# %% [markdown]
# <a href="https://colab.research.google.com/github/dianesophia/Thesis---Inspector-Bill/blob/main/old_money_train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 921.9/921.9 kB 40.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 52.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 29.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 42.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 91.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !yolo task=detect \
     mode=train \
     data=../content/drive/MyDrive/oldMoney_dataset/data.yaml \
     model=yolov8n.pt \
     epochs=50 \
     imgsz=1024 \
     batch=16 \
     lr0=0.003 \
     lrf=0.15 \
     momentum=0.937 \
     weight_decay=0.0005 \
     mixup=0.1 \
     mosaic=0.3 \
     shear=0.1 \
     scale=0.1 \
     hsv_h=0.02 \
     hsv_s=0.8 \
     hsv_v=0.5 \
     flipud=0.0 \
     fliplr=0.5 \
     degrees=2.0 \
     translate=0.1 \
     warmup_epochs=3 \
     warmup_bias_lr=0.05 \
     box=0.1 \
     cls=0.5 \
     perspective=0.0 \
     cache=True \
     rect=True \
     patience=0 \
     save_period=5 \
     project='/content/drive/MyDrive/oldMoney_results' \
     name='old1'
# Out:
# Ultralytics 8.3.78 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# 100 **Epoch**

# %%
# !yolo task=detect \
     mode=train \
     data=../content/drive/MyDrive/oldMoney_dataset/data.yaml \
     model=yolov8n.pt \
     epochs=100 \
     imgsz=1024 \
     batch=16 \
     lr0=0.003 \
     lrf=0.15 \
     momentum=0.937 \
     weight_decay=0.0005 \
     mixup=0.1 \
     mosaic=0.3 \
     shear=0.1 \
     scale=0.1 \
     hsv_h=0.02 \
     hsv_s=0.8 \
     hsv_v=0.5 \
     flipud=0.0 \
     fliplr=0.5 \
     degrees=2.0 \
     translate=0.1 \
     warmup_epochs=3 \
     warmup_bias_lr=0.05 \
     box=0.1 \
     cls=0.5 \
     perspective=0.0 \
     cache=True \
     rect=True \
     patience=0 \
     save_period=5 \
     project='/content/drive/MyDrive/oldMoney_results' \
     name='old1'
# Out:
# Ultralytics 8.3.78 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo task=detect \
     mode=train \
      data=../content/drive/MyDrive/oldMoney_dataset/data.yaml \
     model=../content/drive/MyDrive/oldMoney_results/old14/weights/last.pt \
     epochs=70 \
     imgsz=1024 \
     batch=16 \
     lr0=0.003 \
     lrf=0.15 \
     momentum=0.937 \
     weight_decay=0.0005 \
     mixup=0.1 \
     mosaic=0.3 \
     shear=0.1 \
     scale=0.1 \
     hsv_h=0.02 \
     hsv_s=0.8 \
     hsv_v=0.5 \
     flipud=0.0 \
     fliplr=0.5 \
     degrees=2.0 \
     translate=0.1 \
     warmup_epochs=3 \
     warmup_bias_lr=0.05 \
     box=0.1 \
     cls=0.5 \
     perspective=0.0 \
     cache=True \
     rect=True \
     patience=0 \
     save_period=5 \
     project='/content/drive/MyDrive/oldMoney_results' \
     name='old124' \
     resume=True
# Out:
# Ultralytics 8.3.80 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# 150 Epoch

# %%
# !yolo task=detect \
     mode=train \
     data=../content/drive/MyDrive/oldMoney_dataset/data.yaml \
     model=yolov8n.pt \
     epochs=150 \
     imgsz=1024 \
     batch=16 \
     lr0=0.003 \
     lrf=0.15 \
     momentum=0.937 \
     weight_decay=0.0005 \
     mixup=0.1 \
     mosaic=0.3 \
     shear=0.1 \
     scale=0.1 \
     hsv_h=0.02 \
     hsv_s=0.8 \
     hsv_v=0.5 \
     flipud=0.0 \
     fliplr=0.5 \
     degrees=2.0 \
     translate=0.1 \
     warmup_epochs=3 \
     warmup_bias_lr=0.05 \
     box=0.1 \
     cls=0.5 \
     perspective=0.0 \
     cache=True \
     rect=True \
     patience=0 \
     save_period=5 \
     project='/content/drive/MyDrive/oldMoney_results' \
     name='old1'
# Out:
# ...
# 100% 6.25M/6.25M [00:00<00:00, 149MB/s]
# Ultralytics 8.3.80 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...
